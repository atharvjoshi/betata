# %% [markdown]
# ### Add fabrication, simulation, and measurement metadata for R74_F11_6p92

# %%
from pathlib import Path
from betata.resonator_studies.resonator import Resonator, save_resonator, add_spr_metadata, add_inductance_metadata

CWD = Path.cwd()

# %%
resonator_name = "R74_F11_6p92"
resonator_file = CWD / f"out/resonator_studies/{resonator_name}.h5"

# %%
resonator = Resonator(
    name=resonator_name,
    type="CPW",
    design_name="TAHP02KI-200",
    cooldown_name="2025-09-23_BFD",
    film_thickness=200e-9, # TODO AFM
    pitch=14e-6,
    length=2849.82e-6,
    line_attenuation=81.75,
)
resonator = add_spr_metadata(resonator)
resonator = add_inductance_metadata(resonator)

# %%
save_resonator(resonator, resonator_file)
