# %% [markdown]
# ### Add fabrication, simulation, and measurement metadata for R56_F8_6p16

# %%
from pathlib import Path
from betata.resonator_studies.resonator import Resonator, save_resonator, add_spr_metadata, add_inductance_metadata

CWD = Path.cwd()

# %%
resonator_name = "R56_F8_6p16"
resonator_file = CWD / f"out/resonator_studies/{resonator_name}.h5"

# %%
resonator = Resonator(
    name=resonator_name,
    type="CPW",
    design_name="TAHP02",
    cooldown_name="2025-11-03_BFD",
    film_thickness=1850e-9,
    pitch=6e-6,
    length=4097e-6,
    line_attenuation=85, # TODO find a better estimate
)
resonator = add_spr_metadata(resonator)
resonator = add_inductance_metadata(resonator)

# %%
save_resonator(resonator, resonator_file)
