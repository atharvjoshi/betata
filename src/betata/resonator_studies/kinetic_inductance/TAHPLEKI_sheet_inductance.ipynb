# %% [markdown]
# ### Estimate sheet inductance for resonators of the TAHPLEKI design

# %%
from pathlib import Path

import pandas as pd

from betata import plt, get_blues
from betata.resonator_studies.resonator import load_resonators, map_ls_to_lk, save_resonator

CWD = Path.cwd()

# %% [markdown]
# Load design data file

# %%
design_name = "TAHPLEKI"
design_filepath = CWD / f"data/resonator_studies/{design_name}_lk_sim.csv"
dataframe = pd.read_csv(design_filepath)

# %% [markdown]
# Load resonators

# %%
resonators = load_resonators()

# %% [markdown]
# Map kinetic inductance to sheet inductance

# %%
result = map_ls_to_lk(dataframe)
pitch_nsq_map = {}

# %%
fig, ax = plt.subplots(figsize=(6, 6))
blues = get_blues(len(result.keys()), start=0.3, stop=1.0)

for idx, (pitch, (l_sheet, l_kin, fit_result)) in enumerate(result.items()):

    print("-"*100)
    print(f"{pitch} um")
    print(fit_result.fit_report())
    print("-"*100)

    ax.plot(l_sheet, fit_result.best_fit, "--", color=blues[idx])
    N_sq = fit_result.best_values["nsq"]
    N_sq_err = fit_result.params["nsq"].stderr
    label = f"{pitch} " + r"$\mu$m, $N_{sq}$" + f" = {N_sq:.0f}"
    ax.scatter(l_sheet, l_kin, label=label, color=blues[idx])

    pitch_nsq_map[pitch] = (N_sq, N_sq_err)

ax.set_xlabel(r"$L_s$ (pH/sq)")
ax.set_ylabel(r"$L_k$ (nH)")
ax.legend(bbox_to_anchor=(1.05, 1))
plt.show()
# Out:
# ----------------------------------------------------------------------------------------------------
# 2 um
# [[Model]]
#     Model(fit_fn)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 5
#     # data points      = 20
#     # variables        = 1
#     chi-square         = 0.65802364
#     reduced chi-square = 0.03463282
#     Akaike info crit   = -66.2849340
#     Bayesian info crit = -65.2892017
#     R-squared          = 0.99781071
# [[Variables]]
#     nsq:  230.178527 +/- 1.34678519 (0.59%) (init = 50)
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# 4 um
# [[Model]]
#     Model(fit_fn)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 5
#     # data points      = 20
#     # variables        = 1
#     chi-square         = 0.29377969
#     reduced chi-square = 0.01546209
#     Akaike info crit   = -82.4131483
#     Bayesian info crit = -81.4174160
#     R-squared          = 0.99742122
# [[Variables]]
#     nsq:  142.855502 +/- 0.89988802 (0.63%) (init = 50)
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# 6 um
# [[Model]]
#     Model(fit_fn)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 5
#     # data points      = 20
#     # variables        = 1
#     chi-square         = 0.15821851
#     reduced chi-square = 0.00832729
#     Akaike info crit   = -94.7902101
#     Bayesian info crit = -93.7944778
#     R-squared          = 0.99739700
# [[Variables]]
#     nsq:  104.596923 +/- 0.66039873 (0.63%) (init = 50)
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# 8 um
# [[Model]]
#     Model(fit_fn)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 5
#     # data points      = 20
#     # variables        = 1
#     chi-square         = 0.12243198
#     reduced chi-square = 0.00644379
#     Akaike info crit   = -99.9186380
#     Bayesian info crit = -98.9229058
#     R-squared          = 0.99656592
# [[Variables]]
#     nsq:  80.5718363 +/- 0.58093164 (0.72%) (init = 50)
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# 10 um
# [[Model]]
#     Model(fit_fn)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 5
#     # data points      = 20
#     # variables        = 1
#     chi-square         = 0.09623048
#     reduced chi-square = 0.00506476
#     Akaike info crit   = -104.734828
#     Bayesian info crit = -103.739096
#     R-squared          = 0.99590322
# [[Variables]]
#     nsq:  65.5612308 +/- 0.51503164 (0.79%) (init = 50)
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# 15 um
# [[Model]]
#     Model(fit_fn)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 5
#     # data points      = 20
#     # variables        = 1
#     chi-square         = 0.36339008
#     reduced chi-square = 0.01912579
#     Akaike info crit   = -78.1602141
#     Bayesian info crit = -77.1644819
#     R-squared          = 0.99980419
# [[Variables]]
#     nsq:  561.458200 +/- 1.00083876 (0.18%) (init = 50)
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# 16 um
# [[Model]]
#     Model(fit_fn)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 5
#     # data points      = 20
#     # variables        = 1
#     chi-square         = 0.11514010
#     reduced chi-square = 0.00606001
#     Akaike info crit   = -101.146758
#     Bayesian info crit = -100.151026
#     R-squared          = 0.98970933
# [[Variables]]
#     nsq:  45.9201964 +/- 0.56336632 (1.23%) (init = 50)
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# 35 um
# [[Model]]
#     Model(fit_fn)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 5
#     # data points      = 20
#     # variables        = 1
#     chi-square         = 1.36797113
#     reduced chi-square = 0.07199848
#     Akaike info crit   = -51.6480712
#     Bayesian info crit = -50.6523389
#     R-squared          = 0.99935904
# [[Variables]]
#     nsq:  596.784026 +/- 1.94185165 (0.33%) (init = 50)
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# 65 um
# [[Model]]
#     Model(fit_fn)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 5
#     # data points      = 20
#     # variables        = 1
#     chi-square         = 0.74972681
#     reduced chi-square = 0.03945931
#     Akaike info crit   = -63.6755733
#     Bayesian info crit = -62.6798410
#     R-squared          = 0.99970825
# [[Variables]]
#     nsq:  655.196858 +/- 1.43757034 (0.22%) (init = 50)
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# 100 um
# [[Model]]
#     Model(fit_fn)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 5
#     # data points      = 20
#     # variables        = 1
#     chi-square         = 0.19672827
#     reduced chi-square = 0.01035412
#     Akaike info crit   = -90.4332828
#     Bayesian info crit = -89.4375505
#     R-squared          = 0.99994101
# [[Variables]]
#     nsq:  750.628478 +/- 0.73639523 (0.10%) (init = 50)
# ----------------------------------------------------------------------------------------------------

# %% [markdown]
# Save N_sq in resonator data file

# %%
for resonator in resonators:
    if design_name == resonator.design_name:
        pitch = int(resonator.pitch * 1e6)
        resonator.N_sq, resonator.N_sq_err = pitch_nsq_map[pitch]
        save_resonator(resonator)
