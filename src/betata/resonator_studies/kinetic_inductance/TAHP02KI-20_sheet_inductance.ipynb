# %% [markdown]
# ### Estimate sheet inductance for resonators of the TAHP02KI-20 design

# %%
from pathlib import Path

import pandas as pd

from betata import plt, get_blues
from betata.resonator_studies.resonator import load_resonators, map_ls_to_lk, save_resonator

CWD = Path.cwd()

# %% [markdown]
# Load design data file

# %%
design_name = "TAHP02KI-20"
design_filepath = CWD / f"data/resonator_studies/{design_name}_lk_sim.csv"
dataframe = pd.read_csv(design_filepath)

# %% [markdown]
# Load resonators

# %%
resonators = load_resonators()

# %% [markdown]
# Map kinetic inductance to sheet inductance

# %%
result = map_ls_to_lk(dataframe)
pitch_nsq_map = {}

# %%
fig, ax = plt.subplots(figsize=(6, 6))
blues = get_blues(len(result.keys()), start=0.3, stop=1.0)

for idx, (pitch, (l_sheet, l_kin, fit_result)) in enumerate(result.items()):

    print("-"*100)
    print(f"{pitch} um")
    print(fit_result.fit_report())
    print("-"*100)

    ax.plot(l_sheet, fit_result.best_fit, "--", color=blues[idx])
    N_sq = fit_result.best_values["nsq"]
    N_sq_err = fit_result.params["nsq"].stderr
    label = f"{pitch} " + r"$\mu$m, $N_{sq}$" + f" = {N_sq:.0f}"
    ax.scatter(l_sheet, l_kin, label=label, color=blues[idx])

    pitch_nsq_map[pitch] = (N_sq, N_sq_err)

ax.set_xlabel(r"$L_s$ (pH/sq)")
ax.set_ylabel(r"$L_k$ (nH)")
ax.legend(bbox_to_anchor=(1.05, 1))
plt.show()
# Out:
# ----------------------------------------------------------------------------------------------------
# 2 um
# [[Model]]
#     Model(fit_fn)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 5
#     # data points      = 32
#     # variables        = 1
#     chi-square         = 0.15399438
#     reduced chi-square = 0.00496756
#     Akaike info crit   = -168.770403
#     Bayesian info crit = -167.304667
#     R-squared          = 0.99993332
# [[Variables]]
#     nsq:  92.0309142 +/- 0.07051884 (0.08%) (init = 50)
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# 4 um
# [[Model]]
#     Model(fit_fn)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 5
#     # data points      = 32
#     # variables        = 1
#     chi-square         = 2.98073358
#     reduced chi-square = 0.09615270
#     Akaike info crit   = -73.9541269
#     Bayesian info crit = -72.4883910
#     R-squared          = 0.99652056
# [[Variables]]
#     nsq:  56.5164402 +/- 0.31025179 (0.55%) (init = 50)
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# 6 um
# [[Model]]
#     Model(fit_fn)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 5
#     # data points      = 32
#     # variables        = 1
#     chi-square         = 1.01584776
#     reduced chi-square = 0.03276928
#     Akaike info crit   = -108.400397
#     Bayesian info crit = -106.934661
#     R-squared          = 0.99780835
# [[Variables]]
#     nsq:  41.7045219 +/- 0.18112026 (0.43%) (init = 50)
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# 8 um
# [[Model]]
#     Model(fit_fn)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 5
#     # data points      = 32
#     # variables        = 1
#     chi-square         = 0.50677419
#     reduced chi-square = 0.01634755
#     Akaike info crit   = -130.653621
#     Bayesian info crit = -129.187885
#     R-squared          = 0.99830674
# [[Variables]]
#     nsq:  33.3288595 +/- 0.12792633 (0.38%) (init = 50)
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# 10 um
# [[Model]]
#     Model(fit_fn)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 5
#     # data points      = 32
#     # variables        = 1
#     chi-square         = 0.11909000
#     reduced chi-square = 0.00384161
#     Akaike info crit   = -176.995574
#     Bayesian info crit = -175.529838
#     R-squared          = 0.99942959
# [[Variables]]
#     nsq:  27.9734880 +/- 0.06201409 (0.22%) (init = 50)
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# 12 um
# [[Model]]
#     Model(fit_fn)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 5
#     # data points      = 32
#     # variables        = 1
#     chi-square         = 0.11943413
#     reduced chi-square = 0.00385271
#     Akaike info crit   = -176.903237
#     Bayesian info crit = -175.437501
#     R-squared          = 0.99924585
# [[Variables]]
#     nsq:  24.3546447 +/- 0.06210362 (0.25%) (init = 50)
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# 14 um
# [[Model]]
#     Model(fit_fn)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 5
#     # data points      = 32
#     # variables        = 1
#     chi-square         = 0.13643259
#     reduced chi-square = 0.00440105
#     Akaike info crit   = -172.645138
#     Bayesian info crit = -171.179402
#     R-squared          = 0.99895098
# [[Variables]]
#     nsq:  22.1633921 +/- 0.06637611 (0.30%) (init = 50)
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# 16 um
# [[Model]]
#     Model(fit_fn)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 5
#     # data points      = 32
#     # variables        = 1
#     chi-square         = 0.11974407
#     reduced chi-square = 0.00386271
#     Akaike info crit   = -176.820303
#     Bayesian info crit = -175.354567
#     R-squared          = 0.99884823
# [[Variables]]
#     nsq:  19.7618555 +/- 0.06218415 (0.31%) (init = 50)
# ----------------------------------------------------------------------------------------------------

# %% [markdown]
# Save N_sq in resonator data file

# %%
for resonator in resonators:
    if design_name == resonator.design_name:
        pitch = int(resonator.pitch * 1e6)
        resonator.N_sq, resonator.N_sq_err = pitch_nsq_map[pitch]
        save_resonator(resonator)
