# %% [markdown]
# ### Estimate sheet inductance for resonators of the TAHP02KI-100 design

# %%
from pathlib import Path

import pandas as pd

from betata import plt, get_blues
from betata.resonator_studies.resonator import load_resonators, map_ls_to_lk, save_resonator

CWD = Path.cwd()

# %% [markdown]
# Load design data file

# %%
design_name = "TAHP02KI-100"
design_filepath = CWD / f"data/resonator_studies/{design_name}_lk_sim.csv"
dataframe = pd.read_csv(design_filepath)

# %% [markdown]
# Load resonators

# %%
resonators = load_resonators()

# %% [markdown]
# Map kinetic inductance to sheet inductance

# %%
result = map_ls_to_lk(dataframe)
pitch_nsq_map = {}

# %%
fig, ax = plt.subplots(figsize=(6, 6))
blues = get_blues(len(result.keys()), start=0.3, stop=1.0)

for idx, (pitch, (l_sheet, l_kin, fit_result)) in enumerate(result.items()):

    print("-"*100)
    print(f"{pitch} um")
    print(fit_result.fit_report())
    print("-"*100)

    ax.plot(l_sheet, fit_result.best_fit, "--", color=blues[idx])
    N_sq = fit_result.best_values["nsq"]
    N_sq_err = fit_result.params["nsq"].stderr
    label = f"{pitch} " + r"$\mu$m, $N_{sq}$" + f" = {N_sq:.0f}"
    ax.scatter(l_sheet, l_kin, label=label, color=blues[idx])

    pitch_nsq_map[pitch] = (N_sq, N_sq_err)

ax.set_xlabel(r"$L_s$ (pH/sq)")
ax.set_ylabel(r"$L_k$ (nH)")
ax.legend(bbox_to_anchor=(1.05, 1))
plt.show()
# Out:
# ----------------------------------------------------------------------------------------------------
# 2 um
# [[Model]]
#     Model(fit_fn)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 5
#     # data points      = 17
#     # variables        = 1
#     chi-square         = 0.13468403
#     reduced chi-square = 0.00841775
#     Akaike info crit   = -80.2466305
#     Bayesian info crit = -79.4134171
#     R-squared          = 0.99885937
# [[Variables]]
#     nsq:  183.721123 +/- 0.79069868 (0.43%) (init = 50)
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# 4 um
# [[Model]]
#     Model(fit_fn)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 5
#     # data points      = 17
#     # variables        = 1
#     chi-square         = 0.11065302
#     reduced chi-square = 0.00691581
#     Akaike info crit   = -83.5876772
#     Bayesian info crit = -82.7544638
#     R-squared          = 0.99668613
# [[Variables]]
#     nsq:  99.2109626 +/- 0.71669537 (0.72%) (init = 50)
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# 6 um
# [[Model]]
#     Model(fit_fn)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 5
#     # data points      = 17
#     # variables        = 1
#     chi-square         = 0.10197774
#     reduced chi-square = 0.00637361
#     Akaike info crit   = -84.9756389
#     Bayesian info crit = -84.1424255
#     R-squared          = 0.99406007
# [[Variables]]
#     nsq:  71.7518939 +/- 0.68802727 (0.96%) (init = 50)
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# 8 um
# [[Model]]
#     Model(fit_fn)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 5
#     # data points      = 17
#     # variables        = 1
#     chi-square         = 0.06255506
#     reduced chi-square = 0.00390969
#     Akaike info crit   = -93.2836640
#     Bayesian info crit = -92.4504507
#     R-squared          = 0.99459763
# [[Variables]]
#     nsq:  58.4053476 +/- 0.53887024 (0.92%) (init = 50)
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# 10 um
# [[Model]]
#     Model(fit_fn)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 5
#     # data points      = 17
#     # variables        = 1
#     chi-square         = 0.04945151
#     reduced chi-square = 0.00309072
#     Akaike info crit   = -97.2795914
#     Bayesian info crit = -96.4463781
#     R-squared          = 0.99385409
# [[Variables]]
#     nsq:  49.4974599 +/- 0.47911829 (0.97%) (init = 50)
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# 12 um
# [[Model]]
#     Model(fit_fn)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 5
#     # data points      = 17
#     # variables        = 1
#     chi-square         = 0.01463932
#     reduced chi-square = 9.1496e-04
#     Akaike info crit   = -117.973384
#     Bayesian info crit = -117.140171
#     R-squared          = 0.99758410
# [[Variables]]
#     nsq:  41.8961007 +/- 0.26068338 (0.62%) (init = 50)
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# 14 um
# [[Model]]
#     Model(fit_fn)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 5
#     # data points      = 17
#     # variables        = 1
#     chi-square         = 0.13879902
#     reduced chi-square = 0.00867494
#     Akaike info crit   = -79.7350072
#     Bayesian info crit = -78.9017939
#     R-squared          = 0.97117129
# [[Variables]]
#     nsq:  39.4621435 +/- 0.80268688 (2.03%) (init = 50)
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# 16 um
# [[Model]]
#     Model(fit_fn)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 5
#     # data points      = 17
#     # variables        = 1
#     chi-square         = 0.03616427
#     reduced chi-square = 0.00226027
#     Akaike info crit   = -102.599248
#     Bayesian info crit = -101.766035
#     R-squared          = 0.99061136
# [[Variables]]
#     nsq:  34.6189171 +/- 0.40972534 (1.18%) (init = 50)
# ----------------------------------------------------------------------------------------------------

# %% [markdown]
# Save N_sq in resonator data file

# %%
for resonator in resonators:
    if design_name == resonator.design_name:
        pitch = int(resonator.pitch * 1e6)
        resonator.N_sq, resonator.N_sq_err = pitch_nsq_map[pitch]
        save_resonator(resonator)
