# %% [markdown]
# ### Estimate sheet inductance for resonators of the TAHP02KI-1000 design

# %%
from pathlib import Path

import pandas as pd

from betata import plt, get_blues
from betata.resonator_studies.resonator import load_resonators, map_ls_to_lk, save_resonator

CWD = Path.cwd()

# %% [markdown]
# Load design data file

# %%
design_name = "TAHP02KI-1000"
design_filepath = CWD / f"data/resonator_studies/{design_name}_lk_sim.csv"
dataframe = pd.read_csv(design_filepath)

# %% [markdown]
# Load resonators

# %%
resonators = load_resonators()

# %% [markdown]
# Map kinetic inductance to sheet inductance

# %%
result = map_ls_to_lk(dataframe)
pitch_nsq_map = {}

# %%
fig, ax = plt.subplots(figsize=(6, 6))
blues = get_blues(len(result.keys()), start=0.3, stop=1.0)

for idx, (pitch, (l_sheet, l_kin, fit_result)) in enumerate(result.items()):

    print("-"*100)
    print(f"{pitch} um")
    print(fit_result.fit_report())
    print("-"*100)

    ax.plot(l_sheet, fit_result.best_fit, "--", color=blues[idx])
    N_sq = fit_result.best_values["nsq"]
    N_sq_err = fit_result.params["nsq"].stderr
    label = f"{pitch} " + r"$\mu$m, $N_{sq}$" + f" = {N_sq:.0f}"
    ax.scatter(l_sheet, l_kin, label=label, color=blues[idx])

    pitch_nsq_map[pitch] = (N_sq, N_sq_err)

ax.set_xlabel(r"$L_s$ (pH/sq)")
ax.set_ylabel(r"$L_k$ (nH)")
ax.legend(bbox_to_anchor=(1.05, 1))
plt.show()
# Out:
# ----------------------------------------------------------------------------------------------------
# 2 um
# [[Model]]
#     Model(fit_fn)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 5
#     # data points      = 22
#     # variables        = 1
#     chi-square         = 0.14053314
#     reduced chi-square = 0.00669205
#     Akaike info crit   = -109.173798
#     Bayesian info crit = -108.082755
#     R-squared          = 0.99514686
# [[Variables]]
#     nsq:  406.587374 +/- 3.01626802 (0.74%) (init = 50)
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# 4 um
# [[Model]]
#     Model(fit_fn)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 5
#     # data points      = 22
#     # variables        = 1
#     chi-square         = 0.13211783
#     reduced chi-square = 0.00629133
#     Akaike info crit   = -110.532278
#     Bayesian info crit = -109.441236
#     R-squared          = 0.98599521
# [[Variables]]
#     nsq:  240.051899 +/- 2.92456499 (1.22%) (init = 50)
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# 6 um
# [[Model]]
#     Model(fit_fn)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 5
#     # data points      = 21
#     # variables        = 1
#     chi-square         = 0.06435354
#     reduced chi-square = 0.00321768
#     Akaike info crit   = -119.545602
#     Bayesian info crit = -118.501080
#     R-squared          = 0.98537772
# [[Variables]]
#     nsq:  169.912588 +/- 2.09472333 (1.23%) (init = 50)
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# 8 um
# [[Model]]
#     Model(fit_fn)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 5
#     # data points      = 21
#     # variables        = 1
#     chi-square         = 0.04759487
#     reduced chi-square = 0.00237974
#     Akaike info crit   = -125.880608
#     Bayesian info crit = -124.836086
#     R-squared          = 0.98253101
# [[Variables]]
#     nsq:  132.724306 +/- 1.80359636 (1.36%) (init = 50)
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# 10 um
# [[Model]]
#     Model(fit_fn)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 5
#     # data points      = 22
#     # variables        = 1
#     chi-square         = 0.11956563
#     reduced chi-square = 0.00569360
#     Akaike info crit   = -112.728511
#     Bayesian info crit = -111.637468
#     R-squared          = 0.93252516
# [[Variables]]
#     nsq:  108.959232 +/- 2.78217050 (2.55%) (init = 50)
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# 12 um
# [[Model]]
#     Model(fit_fn)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 5
#     # data points      = 22
#     # variables        = 1
#     chi-square         = 0.05323694
#     reduced chi-square = 0.00253509
#     Akaike info crit   = -130.528995
#     Bayesian info crit = -129.437952
#     R-squared          = 0.96124009
# [[Variables]]
#     nsq:  94.4821140 +/- 1.85646645 (1.96%) (init = 50)
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# 14 um
# [[Model]]
#     Model(fit_fn)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 5
#     # data points      = 22
#     # variables        = 1
#     chi-square         = 0.04887131
#     reduced chi-square = 0.00232721
#     Akaike info crit   = -132.411358
#     Bayesian info crit = -131.320316
#     R-squared          = 0.95027447
# [[Variables]]
#     nsq:  80.9257881 +/- 1.77871988 (2.20%) (init = 50)
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# 16 um
# [[Model]]
#     Model(fit_fn)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 5
#     # data points      = 22
#     # variables        = 1
#     chi-square         = 0.02363449
#     reduced chi-square = 0.00112545
#     Akaike info crit   = -148.393991
#     Bayesian info crit = -147.302948
#     R-squared          = 0.96794522
# [[Variables]]
#     nsq:  68.9369020 +/- 1.23695448 (1.79%) (init = 50)
# ----------------------------------------------------------------------------------------------------

# %% [markdown]
# Save N_sq in resonator data file

# %%
for resonator in resonators:
    if design_name == resonator.design_name:
        pitch = int(resonator.pitch * 1e6)
        resonator.N_sq, resonator.N_sq_err = pitch_nsq_map[pitch]
        save_resonator(resonator)
