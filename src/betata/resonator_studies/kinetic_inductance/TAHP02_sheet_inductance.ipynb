# %% [markdown]
# ### Estimate sheet inductance for resonators of the TAHP02 design

# %%
from pathlib import Path

import pandas as pd

from betata import plt, get_blues
from betata.resonator_studies.resonator import load_resonators, map_ls_to_lk, save_resonator

CWD = Path.cwd()

# %% [markdown]
# Load design data file

# %%
design_name = "TAHP02"
design_filepath = CWD / f"data/resonator_studies/{design_name}_lk_sim.csv"
dataframe = pd.read_csv(design_filepath)

# %% [markdown]
# Load resonators

# %%
resonators = load_resonators()

# %% [markdown]
# Map kinetic inductance to sheet inductance

# %%
result = map_ls_to_lk(dataframe)
pitch_nsq_map = {}

# %%
fig, ax = plt.subplots(figsize=(6, 6))
blues = get_blues(len(result.keys()), start=0.3, stop=1.0)

for idx, (pitch, (l_sheet, l_kin, fit_result)) in enumerate(result.items()):

    print("-"*100)
    print(f"{pitch} um")
    print(fit_result.fit_report())
    print("-"*100)

    ax.plot(l_sheet, fit_result.best_fit, "--", color=blues[idx])
    N_sq = fit_result.best_values["nsq"]
    N_sq_err = fit_result.params["nsq"].stderr
    label = f"{pitch} " + r"$\mu$m, $N_{sq}$" + f" = {N_sq:.0f}"
    ax.scatter(l_sheet, l_kin, label=label, color=blues[idx])

    pitch_nsq_map[pitch] = (N_sq, N_sq_err)

ax.set_xlabel(r"$L_s$ (pH/sq)")
ax.set_ylabel(r"$L_k$ (nH)")
ax.legend(bbox_to_anchor=(1.05, 1))
plt.show()
# Out:
# ----------------------------------------------------------------------------------------------------
# 2 um
# [[Model]]
#     Model(fit_fn)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 5
#     # data points      = 18
#     # variables        = 1
#     chi-square         = 0.89003942
#     reduced chi-square = 0.05235526
#     Akaike info crit   = -52.1235032
#     Bayesian info crit = -51.2331314
#     R-squared          = 0.99339601
# [[Variables]]
#     nsq:  502.724962 +/- 5.12281544 (1.02%) (init = 50)
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# 4 um
# [[Model]]
#     Model(fit_fn)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 5
#     # data points      = 18
#     # variables        = 1
#     chi-square         = 0.31669538
#     reduced chi-square = 0.01862914
#     Akaike info crit   = -70.7233602
#     Bayesian info crit = -69.8329885
#     R-squared          = 0.99129245
# [[Variables]]
#     nsq:  264.381103 +/- 3.05580018 (1.16%) (init = 50)
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# 6 um
# [[Model]]
#     Model(fit_fn)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 5
#     # data points      = 18
#     # variables        = 1
#     chi-square         = 0.14445489
#     reduced chi-square = 0.00849735
#     Akaike info crit   = -84.8528753
#     Bayesian info crit = -83.9625036
#     R-squared          = 0.99059912
# [[Variables]]
#     nsq:  172.317594 +/- 2.06381240 (1.20%) (init = 50)
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# 8 um
# [[Model]]
#     Model(fit_fn)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 5
#     # data points      = 18
#     # variables        = 1
#     chi-square         = 0.10879618
#     reduced chi-square = 0.00639978
#     Akaike info crit   = -89.9557149
#     Bayesian info crit = -89.0653432
#     R-squared          = 0.98697472
# [[Variables]]
#     nsq:  128.500902 +/- 1.79106319 (1.39%) (init = 50)
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# 10 um
# [[Model]]
#     Model(fit_fn)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 5
#     # data points      = 17
#     # variables        = 1
#     chi-square         = 0.14311413
#     reduced chi-square = 0.00894463
#     Akaike info crit   = -79.2145453
#     Bayesian info crit = -78.3813319
#     R-squared          = 0.98135968
# [[Variables]]
#     nsq:  141.903448 +/- 2.36810483 (1.67%) (init = 50)
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# 12 um
# [[Model]]
#     Model(fit_fn)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 5
#     # data points      = 18
#     # variables        = 1
#     chi-square         = 0.11519919
#     reduced chi-square = 0.00677642
#     Akaike info crit   = -88.9263582
#     Bayesian info crit = -88.0359864
#     R-squared          = 0.98189153
# [[Variables]]
#     nsq:  113.864160 +/- 1.84301469 (1.62%) (init = 50)
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# 14 um
# [[Model]]
#     Model(fit_fn)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 5
#     # data points      = 18
#     # variables        = 1
#     chi-square         = 0.08813092
#     reduced chi-square = 0.00518417
#     Akaike info crit   = -93.7474641
#     Bayesian info crit = -92.8570923
#     R-squared          = 0.98017527
# [[Variables]]
#     nsq:  95.3719799 +/- 1.61201193 (1.69%) (init = 50)
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# 16 um
# [[Model]]
#     Model(fit_fn)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 5
#     # data points      = 18
#     # variables        = 1
#     chi-square         = 0.06132632
#     reduced chi-square = 0.00360743
#     Akaike info crit   = -100.274523
#     Bayesian info crit = -99.3841511
#     R-squared          = 0.98097647
# [[Variables]]
#     nsq:  80.7761905 +/- 1.34470661 (1.66%) (init = 50)
# ----------------------------------------------------------------------------------------------------

# %% [markdown]
# Save N_sq in resonator data file

# %%
for resonator in resonators:
    if design_name == resonator.design_name:
        pitch = int(resonator.pitch * 1e6)
        resonator.N_sq, resonator.N_sq_err = pitch_nsq_map[pitch]
        save_resonator(resonator)
