# %% [markdown]
# ### Estimate sheet inductance for resonators of the TAHP02KI-50 design

# %%
from pathlib import Path

import pandas as pd

from betata import plt, get_blues
from betata.resonator_studies.resonator import load_resonators, map_ls_to_lk, save_resonator

CWD = Path.cwd()

# %% [markdown]
# Load design data file

# %%
design_name = "TAHP02KI-50"
design_filepath = CWD / f"data/resonator_studies/{design_name}_lk_sim.csv"
dataframe = pd.read_csv(design_filepath)

# %% [markdown]
# Load resonators

# %%
resonators = load_resonators()

# %% [markdown]
# Map kinetic inductance to sheet inductance

# %%
result = map_ls_to_lk(dataframe)
pitch_nsq_map = {}

# %%
fig, ax = plt.subplots(figsize=(6, 6))
blues = get_blues(len(result.keys()), start=0.3, stop=1.0)

for idx, (pitch, (l_sheet, l_kin, fit_result)) in enumerate(result.items()):

    print("-"*100)
    print(f"{pitch} um")
    print(fit_result.fit_report())
    print("-"*100)

    ax.plot(l_sheet, fit_result.best_fit, "--", color=blues[idx])
    N_sq = fit_result.best_values["nsq"]
    N_sq_err = fit_result.params["nsq"].stderr
    label = f"{pitch} " + r"$\mu$m, $N_{sq}$" + f" = {N_sq:.0f}"
    ax.scatter(l_sheet, l_kin, label=label, color=blues[idx])

    pitch_nsq_map[pitch] = (N_sq, N_sq_err)

ax.set_xlabel(r"$L_s$ (pH/sq)")
ax.set_ylabel(r"$L_k$ (nH)")
ax.legend(bbox_to_anchor=(1.05, 1))
plt.show()
# Out:
# ----------------------------------------------------------------------------------------------------
# 2 um
# [[Model]]
#     Model(fit_fn)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 5
#     # data points      = 21
#     # variables        = 1
#     chi-square         = 0.33563763
#     reduced chi-square = 0.01678188
#     Akaike info crit   = -84.8611578
#     Bayesian info crit = -83.8166353
#     R-squared          = 0.99933574
# [[Variables]]
#     nsq:  165.014634 +/- 0.48362570 (0.29%) (init = 50)
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# 4 um
# [[Model]]
#     Model(fit_fn)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 5
#     # data points      = 21
#     # variables        = 1
#     chi-square         = 0.22151443
#     reduced chi-square = 0.01107572
#     Akaike info crit   = -93.5875900
#     Bayesian info crit = -92.5430675
#     R-squared          = 0.99845825
# [[Variables]]
#     nsq:  88.4059303 +/- 0.39289369 (0.44%) (init = 50)
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# 6 um
# [[Model]]
#     Model(fit_fn)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 5
#     # data points      = 21
#     # variables        = 1
#     chi-square         = 0.07982283
#     reduced chi-square = 0.00399114
#     Akaike info crit   = -115.021832
#     Bayesian info crit = -113.977310
#     R-squared          = 0.99892323
# [[Variables]]
#     nsq:  63.3086620 +/- 0.23585093 (0.37%) (init = 50)
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# 8 um
# [[Model]]
#     Model(fit_fn)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 5
#     # data points      = 21
#     # variables        = 1
#     chi-square         = 0.10127770
#     reduced chi-square = 0.00506389
#     Akaike info crit   = -110.022640
#     Bayesian info crit = -108.978118
#     R-squared          = 0.99793254
# [[Variables]]
#     nsq:  52.0550105 +/- 0.26566294 (0.51%) (init = 50)
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# 10 um
# [[Model]]
#     Model(fit_fn)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 5
#     # data points      = 20
#     # variables        = 1
#     chi-square         = 0.06667368
#     reduced chi-square = 0.00350914
#     Akaike info crit   = -112.073546
#     Bayesian info crit = -111.077814
#     R-squared          = 0.99813700
# [[Variables]]
#     nsq:  44.9728871 +/- 0.22911298 (0.51%) (init = 50)
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# 12 um
# [[Model]]
#     Model(fit_fn)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 5
#     # data points      = 21
#     # variables        = 1
#     chi-square         = 0.06213172
#     reduced chi-square = 0.00310659
#     Akaike info crit   = -120.283441
#     Bayesian info crit = -119.238919
#     R-squared          = 0.99776011
# [[Variables]]
#     nsq:  39.2886481 +/- 0.20808020 (0.53%) (init = 50)
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# 14 um
# [[Model]]
#     Model(fit_fn)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 5
#     # data points      = 21
#     # variables        = 1
#     chi-square         = 0.05296244
#     reduced chi-square = 0.00264812
#     Akaike info crit   = -123.636590
#     Bayesian info crit = -122.592068
#     R-squared          = 0.99751663
# [[Variables]]
#     nsq:  34.5142997 +/- 0.19211357 (0.56%) (init = 50)
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# 16 um
# [[Model]]
#     Model(fit_fn)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 5
#     # data points      = 21
#     # variables        = 1
#     chi-square         = 0.06186701
#     reduced chi-square = 0.00309335
#     Akaike info crit   = -120.373102
#     Bayesian info crit = -119.328580
#     R-squared          = 0.99634405
# [[Variables]]
#     nsq:  30.8685017 +/- 0.20763647 (0.67%) (init = 50)
# ----------------------------------------------------------------------------------------------------

# %% [markdown]
# Save N_sq in resonator data file

# %%
for resonator in resonators:
    if design_name == resonator.design_name:
        pitch = int(resonator.pitch * 1e6)
        resonator.N_sq, resonator.N_sq_err = pitch_nsq_map[pitch]
        save_resonator(resonator)
