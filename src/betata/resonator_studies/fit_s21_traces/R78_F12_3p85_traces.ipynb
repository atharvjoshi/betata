# %% [markdown]
# ### Fit S21 traces for R78_F12_3p85

# %%
from pathlib import Path
from rrfit.hangerfit import fit_s21_v2
from betata.resonator_studies.trace import Trace, load_traces, save_traces

CWD = Path.cwd()

# %% [markdown]
# Specify input folder and output file

# %%
resonator_name = "R78_F12_3p85"
input_folder = CWD / f"data/resonator_studies/{resonator_name}"
output_file = CWD / f"out/resonator_studies/{resonator_name}.h5"

# %% [markdown]
# Load traces

# %%
traces: list[Trace] = load_traces(input_folder)

# %% [markdown]
# Fit traces

# %%
for trace in traces:
    plot_title = f"Device {trace.resonator_name}, Trace #{trace.id}, Power {trace.power} dBm, Temp {trace.temperature * 1e3:.1f}mK"
    fit_s21_v2(trace, plot_title=plot_title)
# Out:
# [[Model]]
#     Model(S21Model)
# [[Fit Statistics]]
#     # fitting method   = least_squares
#     # function evals   = 45
#     # data points      = 480
#     # variables        = 4
#     chi-square         = 0.89507200
#     reduced chi-square = 0.00188040
#     Akaike info crit   = -3008.62587
#     Bayesian info crit = -2991.93072
#     R-squared          = np.complex128(7918046727543.884+112046306531540.36j)
# [[Variables]]
#     fr:     3.8469e+09 +/- 6.33214955 (0.00%) (init = 3.846948e+09)
#     Ql:     4395670.39 +/- 63367.1602 (1.44%) (init = 4646565)
#     absQc:  6976713.18 +/- 86197.2601 (1.24%) (init = 7272600)
#     phi:    0.03580298 +/- 0.01242569 (34.71%) (init = 0.04001532)
#     a:      1 (fixed)
#     alpha:  0 (fixed)
#     tau:    0 (fixed)
#     Qi:     11868806.3 +/- 277896.211 (2.34%) == '1 / ((1 / Ql) - (cos(phi) / absQc))'
# [[Correlations]] (unreported correlations are < 0.100)
#     C(fr, phi)   = -0.8700
#     C(Ql, absQc) = +0.8655
#     C(fr, Ql)    = +0.1736
#     C(Ql, phi)   = -0.1465
# [[Model]]
#     Model(S21Model)
# [[Fit Statistics]]
#     # fitting method   = least_squares
#     # function evals   = 30
#     # data points      = 480
#     # variables        = 4
#     chi-square         = 0.00944674
#     reduced chi-square = 1.9846e-05
#     Akaike info crit   = -5193.21826
#     Bayesian info crit = -5176.52312
#     R-squared          = np.complex128(264941184345.24762-463832892349.07166j)
# [[Variables]]
#     fr:     3.8469e+09 +/- 0.85564135 (0.00%) (init = 3.846948e+09)
#     Ql:     3778993.94 +/- 6204.90856 (0.16%) (init = 4631375)
#     absQc:  6269699.75 +/- 8399.08696 (0.13%) (init = 7681759)
#     phi:   -0.14158489 +/- 0.00138705 (0.98%) (init = -0.141719)
#     a:      1 (fixed)
#     alpha:  0 (fixed)
#     tau:    0 (fixed)
#     Qi:     9370365.92 +/- 24334.7491 (0.26%) == '1 / ((1 / Ql) - (cos(phi) / absQc))'
# [[Correlations]] (unreported correlations are < 0.100)
#     C(fr, phi)   = -0.8423
#     C(Ql, absQc) = +0.8114
#     C(Ql, phi)   = -0.3364
#     C(fr, absQc) = -0.1652
#     C(fr, Ql)    = +0.1434
# [[Model]]
#     Model(S21Model)
# [[Fit Statistics]]
#     # fitting method   = least_squares
#     # function evals   = 30
#     # data points      = 480
#     # variables        = 4
#     chi-square         = 0.02765515
#     reduced chi-square = 5.8099e-05
#     Akaike info crit   = -4677.63015
#     Bayesian info crit = -4660.93501
#     R-squared          = np.complex128(-1157936753020.1875-2657484492372.7515j)
# [[Variables]]
#     fr:     3.8469e+09 +/- 1.57581987 (0.00%) (init = 3.846948e+09)
#     Ql:     3466358.14 +/- 9879.08565 (0.28%) (init = 3980282)
#     absQc:  6215807.88 +/- 15339.8186 (0.25%) (init = 7130349)
#     phi:   -0.15184151 +/- 0.00245466 (1.62%) (init = -0.1521813)
#     a:      1 (fixed)
#     alpha:  0 (fixed)
#     tau:    0 (fixed)
#     Qi:     7724505.03 +/- 30855.9211 (0.40%) == '1 / ((1 / Ql) - (cos(phi) / absQc))'
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ql, absQc) = +0.8735
#     C(fr, phi)   = -0.8692
#     C(fr, Ql)    = +0.1385
#     C(fr, absQc) = +0.1313
# [[Model]]
#     Model(S21Model)
# [[Fit Statistics]]
#     # fitting method   = least_squares
#     # function evals   = 28
#     # data points      = 480
#     # variables        = 4
#     chi-square         = 0.12634603
#     reduced chi-square = 2.6543e-04
#     Akaike info crit   = -3948.40816
#     Bayesian info crit = -3931.71301
#     R-squared          = np.complex128(19760575700860.61+6765244067808.563j)
# [[Variables]]
#     fr:     3.8469e+09 +/- 4.11422590 (0.00%) (init = 3.846948e+09)
#     Ql:     3124668.19 +/- 21028.7334 (0.67%) (init = 3650895)
#     absQc:  6140030.49 +/- 35672.1927 (0.58%) (init = 7133783)
#     phi:   -0.18678149 +/- 0.00574959 (3.08%) (init = -0.1892939)
#     a:      1 (fixed)
#     alpha:  0 (fixed)
#     tau:    0 (fixed)
#     Qi:     6249958.43 +/- 56135.5929 (0.90%) == '1 / ((1 / Ql) - (cos(phi) / absQc))'
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ql, absQc) = +0.8710
#     C(fr, phi)   = -0.8626
#     C(fr, absQc) = +0.1678
#     C(fr, Ql)    = +0.1244
# [[Model]]
#     Model(S21Model)
# [[Fit Statistics]]
#     # fitting method   = least_squares
#     # function evals   = 26
#     # data points      = 480
#     # variables        = 4
#     chi-square         = 0.64420877
#     reduced chi-square = 0.00135338
#     Akaike info crit   = -3166.48889
#     Bayesian info crit = -3149.79375
#     R-squared          = np.complex128(0.9471045654644991-0.05572731094601775j)
# [[Variables]]
#     fr:     3.8469e+09 +/- 12.6189005 (0.00%) (init = 3.846947e+09)
#     Ql:     2665321.19 +/- 47235.7843 (1.77%) (init = 3288555)
#     absQc:  5806093.46 +/- 86306.6617 (1.49%) (init = 6934250)
#     phi:   -0.19997791 +/- 0.01456781 (7.28%) (init = -0.2140504)
#     a:      1 (fixed)
#     alpha:  0 (fixed)
#     tau:    0 (fixed)
#     Qi:     4845222.01 +/- 113752.079 (2.35%) == '1 / ((1 / Ql) - (cos(phi) / absQc))'
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ql, absQc) = +0.8479
#     C(fr, phi)   = -0.8306
#     C(fr, absQc) = +0.2667
#     C(Ql, phi)   = +0.1402
#     C(fr, Ql)    = +0.1028
# [[Model]]
#     Model(S21Model)
# [[Fit Statistics]]
#     # fitting method   = least_squares
#     # function evals   = 25
#     # data points      = 480
#     # variables        = 4
#     chi-square         = 3.30015140
#     reduced chi-square = 0.00693309
#     Akaike info crit   = -2382.31252
#     Bayesian info crit = -2365.61738
#     R-squared          = np.complex128(-90110480667070.3+160877127572490.47j)
# [[Variables]]
#     fr:     3.8469e+09 +/- 34.5382501 (0.00%) (init = 3.846946e+09)
#     Ql:     2453341.89 +/- 109979.479 (4.48%) (init = 2803009)
#     absQc:  5153960.28 +/- 176702.742 (3.43%) (init = 5289626)
#     phi:   -0.07224809 +/- 0.03341498 (46.25%) (init = -0.2073852)
#     a:      1 (fixed)
#     alpha:  0 (fixed)
#     tau:    0 (fixed)
#     Qi:     4670978.93 +/- 304226.492 (6.51%) == '1 / ((1 / Ql) - (cos(phi) / absQc))'
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ql, absQc) = +0.7771
#     C(fr, phi)   = -0.7506
#     C(fr, absQc) = +0.3611
#     C(Ql, phi)   = +0.2689

# %% [markdown]
# Exclude traces

# %%
traces_to_exclude = []
for trace in traces:
    if trace.id in traces_to_exclude:
        trace.is_excluded = True
    else:
        trace.is_excluded = False

# %% [markdown]
# Save fitted traces

# %%
save_traces(traces, output_file)
