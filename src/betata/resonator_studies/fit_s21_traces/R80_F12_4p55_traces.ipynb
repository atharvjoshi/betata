# %% [markdown]
# ### Fit S21 traces for R80_F12_4p55

# %%
from pathlib import Path
from rrfit.hangerfit import fit_s21_v2
from betata.resonator_studies.trace import Trace, load_traces, save_traces

CWD = Path.cwd()

# %% [markdown]
# Specify input folder and output file

# %%
resonator_name = "R80_F12_4p55"
input_folder = CWD / f"data/resonator_studies/{resonator_name}"
output_file = CWD / f"out/resonator_studies/{resonator_name}.h5"

# %% [markdown]
# Load traces

# %%
traces: list[Trace] = load_traces(input_folder)

# %% [markdown]
# Fit traces

# %%
for trace in traces:
    plot_title = f"Device {trace.resonator_name}, Trace #{trace.id}, Power {trace.power} dBm, Temp {trace.temperature * 1e3:.1f}mK"
    fit_s21_v2(trace, plot_title=plot_title)
# Out:
# [[Model]]
#     Model(S21Model)
# [[Fit Statistics]]
#     # fitting method   = least_squares
#     # function evals   = 26
#     # data points      = 480
#     # variables        = 4
#     chi-square         = 0.44349850
#     reduced chi-square = 9.3172e-04
#     Akaike info crit   = -3345.68654
#     Bayesian info crit = -3328.99140
#     R-squared          = np.complex128(-24654150351612.75-485286496892.3342j)
# [[Variables]]
#     fr:     4.5525e+09 +/- 14.6710162 (0.00%) (init = 4.552486e+09)
#     Ql:     1654178.94 +/- 17647.8161 (1.07%) (init = 2161283)
#     absQc:  2824310.68 +/- 26538.6134 (0.94%) (init = 3642569)
#     phi:   -0.10995285 +/- 0.00938725 (8.54%) (init = -0.1098201)
#     a:      1 (fixed)
#     alpha:  0 (fixed)
#     tau:    0 (fixed)
#     Qi:     3958844.67 +/- 60595.3723 (1.53%) == '1 / ((1 / Ql) - (cos(phi) / absQc))'
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ql, absQc) = +0.8825
#     C(fr, phi)   = -0.8817
# [[Model]]
#     Model(S21Model)
# [[Fit Statistics]]
#     # fitting method   = least_squares
#     # function evals   = 21
#     # data points      = 480
#     # variables        = 4
#     chi-square         = 0.29883368
#     reduced chi-square = 6.2780e-04
#     Akaike info crit   = -3535.19402
#     Bayesian info crit = -3518.49888
#     R-squared          = np.complex128(50406816800553.516-86747158387918.02j)
# [[Variables]]
#     fr:     4.5525e+09 +/- 29.2942590 (0.00%) (init = 4.552486e+09)
#     Ql:     1038235.97 +/- 13883.9549 (1.34%) (init = 1251781)
#     absQc:  2702334.40 +/- 32453.4067 (1.20%) (init = 3195299)
#     phi:   -0.12637962 +/- 0.01199454 (9.49%) (init = -0.1174133)
#     a:      1 (fixed)
#     alpha:  0 (fixed)
#     tau:    0 (fixed)
#     Qi:     1677646.84 +/- 25742.3839 (1.53%) == '1 / ((1 / Ql) - (cos(phi) / absQc))'
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ql, absQc) = +0.8990
#     C(fr, phi)   = -0.8980
# [[Model]]
#     Model(S21Model)
# [[Fit Statistics]]
#     # fitting method   = least_squares
#     # function evals   = 21
#     # data points      = 480
#     # variables        = 4
#     chi-square         = 0.10718638
#     reduced chi-square = 2.2518e-04
#     Akaike info crit   = -4027.34664
#     Bayesian info crit = -4010.65150
#     R-squared          = np.complex128(0.9825980181595839-0.02483039751442887j)
# [[Variables]]
#     fr:     4.5525e+09 +/- 50.7449789 (0.00%) (init = 4.552485e+09)
#     Ql:     631150.677 +/- 8896.03580 (1.41%) (init = 815295.6)
#     absQc:  2856641.34 +/- 35963.8677 (1.26%) (init = 3589029)
#     phi:   -0.08064364 +/- 0.01255671 (15.57%) (init = -0.07094546)
#     a:      1 (fixed)
#     alpha:  0 (fixed)
#     tau:    0 (fixed)
#     Qi:     809399.430 +/- 12153.3860 (1.50%) == '1 / ((1 / Ql) - (cos(phi) / absQc))'
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ql, absQc) = +0.8940
#     C(fr, phi)   = -0.8920
#     C(fr, absQc) = +0.1224
# [[Model]]
#     Model(S21Model)
# [[Fit Statistics]]
#     # fitting method   = least_squares
#     # function evals   = 26
#     # data points      = 480
#     # variables        = 4
#     chi-square         = 0.09853620
#     reduced chi-square = 2.0701e-04
#     Akaike info crit   = -4067.73635
#     Bayesian info crit = -4051.04120
#     R-squared          = np.complex128(-3555067872518.2017+3858857184607.3423j)
# [[Variables]]
#     fr:     4.5525e+09 +/- 128.825301 (0.00%) (init = 4.552485e+09)
#     Ql:     382407.089 +/- 8276.93341 (2.16%) (init = 427799.6)
#     absQc:  2807598.42 +/- 54778.6867 (1.95%) (init = 2982171)
#     phi:   -0.16498133 +/- 0.01950850 (11.82%) (init = -0.1720558)
#     a:      1 (fixed)
#     alpha:  0 (fixed)
#     tau:    0 (fixed)
#     Qi:     441759.654 +/- 9858.59895 (2.23%) == '1 / ((1 / Ql) - (cos(phi) / absQc))'
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ql, absQc) = +0.9015
#     C(fr, phi)   = -0.9015
# [[Model]]
#     Model(S21Model)
# [[Fit Statistics]]
#     # fitting method   = least_squares
#     # function evals   = 35
#     # data points      = 480
#     # variables        = 4
#     chi-square         = 0.43264026
#     reduced chi-square = 9.0891e-04
#     Akaike info crit   = -3357.58470
#     Bayesian info crit = -3340.88956
#     R-squared          = np.complex128(2866181336592.6855-70033066940584.61j)
# [[Variables]]
#     fr:     4.5525e+09 +/- 497.525295 (0.00%) (init = 4.552486e+09)
#     Ql:     210439.843 +/- 9676.54672 (4.60%) (init = 280103.2)
#     absQc:  1552986.57 +/- 64668.3682 (4.16%) (init = 1747249)
#     phi:    0.01172744 +/- 0.04166030 (355.24%) (init = 0.06064359)
#     a:      1 (fixed)
#     alpha:  0 (fixed)
#     tau:    0 (fixed)
#     Qi:     243422.981 +/- 11529.9204 (4.74%) == '1 / ((1 / Ql) - (cos(phi) / absQc))'
# [[Correlations]] (unreported correlations are < 0.100)
#     C(fr, phi)   = -0.9059
#     C(Ql, absQc) = +0.9055
# [[Model]]
#     Model(S21Model)
# [[Fit Statistics]]
#     # fitting method   = least_squares
#     # function evals   = 135
#     # data points      = 480
#     # variables        = 4
#     chi-square         = 2.12126981
#     reduced chi-square = 0.00445645
#     Akaike info crit   = -2594.45019
#     Bayesian info crit = -2577.75504
#     R-squared          = np.complex128(32560015722038.453-54409866248696.42j)
# [[Variables]]
#     fr:     4.5525e+09 +/- 3512822.91 (0.08%) (init = 4.552408e+09)
#     Ql:     1692.45605 +/- 4420.56940 (261.19%) (init = 358143.6)
#     absQc:  14481.0597 +/- 37741.0109 (260.62%) (init = 1580223)
#     phi:    1.14528697 +/- 2.60625740 (227.56%) (init = 1.43268)
#     a:      1 (fixed)
#     alpha:  0 (fixed)
#     tau:    0 (fixed)
#     Qi:     1778.24520 +/- 4709.23528 (264.82%) == '1 / ((1 / Ql) - (cos(phi) / absQc))'
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ql, absQc) = +0.9978
#     C(fr, phi)   = -0.9978

# %% [markdown]
# Exclude traces

# %%
traces_to_exclude = [5]
for trace in traces:
    if trace.id in traces_to_exclude:
        trace.is_excluded = True
    else:
        trace.is_excluded = False

# %% [markdown]
# Save fitted traces

# %%
save_traces(traces, output_file)
