# %% [markdown]
# ### Add fabrication, simulation, and measurement metadata for Q6_4p69

# %%
from pathlib import Path
from betata.qubit_measurements.qubit import Qubit, save_qubit
CWD = Path.cwd()

# %%
qubit_name = "Q6_4p69"
qubit_file = CWD / f"out/qubit_measurements/{qubit_name}.h5"

# %%
qubit = Qubit(
    name=qubit_name,
    design_name="TATQ01KI-V2",
    f_q = 4.696e9,
    f_r = 7.750e9,
    chi = -0.258e6,
    kappa = 0.488e6,
    Ej = 14.85e9,
    Ec = 202e6,
)

# %%
save_qubit(qubit, qubit_file)
