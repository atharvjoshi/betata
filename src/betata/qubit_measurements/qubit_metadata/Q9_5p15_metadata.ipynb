# %% [markdown]
# ### Add fabrication, simulation, and measurement metadata for Q9_5p15

# %%
from pathlib import Path
from betata.qubit_measurements.qubit import Qubit, save_qubit
CWD = Path.cwd()

# %%
qubit_name = "Q9_5p15"
qubit_file = CWD / f"out/qubit_measurements/{qubit_name}.h5"

# %%
qubit = Qubit(
    name=qubit_name,
    design_name="TATQ01KI-V2",
    f_q = 5.145e9,
    f_r = 8.233e9,
    chi = -0.318e6,
    kappa = 0.914e6,
    Ej = 18.73e9,
    Ec = 190e6,
)

# %%
save_qubit(qubit, qubit_file)
