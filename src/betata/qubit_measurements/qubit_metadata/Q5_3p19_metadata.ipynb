# %% [markdown]
# ### Add fabrication, simulation, and measurement metadata for Q5_3p19

# %%
from pathlib import Path
from betata.qubit_measurements.qubit import Qubit, save_qubit
CWD = Path.cwd()

# %%
qubit_name = "Q5_3p19"
qubit_file = CWD / f"out/qubit_measurements/{qubit_name}.h5"

# %%
qubit = Qubit(
    name=qubit_name,
    design_name="TATQ01KI-V1",
    f_q = 3.193e9,
    f_r = 7.031e9,
    chi = -0.198e6,
    kappa = 1.089e6,
    Ej = 7.259e9,
    Ec = 230e6,
)

# %%
save_qubit(qubit, qubit_file)
