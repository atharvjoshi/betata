# %% [markdown]
# ### Add fabrication, simulation, and measurement metadata for Q7_4p83

# %%
from pathlib import Path
from betata.qubit_measurements.qubit import Qubit, save_qubit
CWD = Path.cwd()

# %%
qubit_name = "Q7_4p83"
qubit_file = CWD / f"out/qubit_measurements/{qubit_name}.h5"

# %%
qubit = Qubit(
    name=qubit_name,
    design_name="TATQ01KI-V2",
    f_q = 4.822e9,
    f_r = 7.987e9,
    chi = -0.276e6,
    kappa = 0.299e6,
    Ej = 15.34e9,
    Ec = 206e6,
)

# %%
save_qubit(qubit, qubit_file)
