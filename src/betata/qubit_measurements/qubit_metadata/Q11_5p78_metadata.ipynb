# %% [markdown]
# ### Add fabrication, simulation, and measurement metadata for Q11_5p78

# %%
from pathlib import Path
from betata.qubit_measurements.qubit import Qubit, save_qubit
CWD = Path.cwd()

# %%
qubit_name = "Q11_5p78"
qubit_file = CWD / f"out/qubit_measurements/{qubit_name}.h5"

# %%
qubit = Qubit(
    name=qubit_name,
    design_name="TATQ01KI-V2",
    f_q = 5.804e9,
    f_r = 7.919e9,
    chi = -0.486e6,
    kappa = 0.504e6,
    Ej = 23.41e9,
    Ec = 192e6,
)

# %%
save_qubit(qubit, qubit_file)
