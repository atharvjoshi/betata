# %% [markdown]
# ### Fit T1 traces for Q3_2p88

# %%
from pathlib import Path

from betata.qubit_measurements.qubit import load_qubit, save_qubit
from betata.qubit_measurements.traces import T1Trace, load_t1_traces

CWD = Path.cwd()

# %% [markdown]
# Specify input folder and output file

# %%
qubit_name = "Q3_2p88"
input_folder = CWD / f"data/qubit_measurements/{qubit_name}/T1_{qubit_name}"
output_file = CWD / f"out/qubit_measurements/{qubit_name}.h5"

# %% [markdown]
# Load traces

# %%
traces: list[T1Trace] = load_t1_traces(input_folder)

# %% [markdown]
# Fit traces

# %% [markdown]
# Exclude badly fit traces

# %% [markdown]
# Save fit results
